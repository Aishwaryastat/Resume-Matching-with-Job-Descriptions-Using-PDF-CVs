# %% [markdown]
# # PDF Data Extraction

# %%
# Load nessesary libraries
import os
import pandas as pd
import PyPDF2
import re 
import numpy as np

# %%
# Build a pdf extractor
def extract_resume_data(file_path):
    resume_data = []
    
    if file_path.endswith('.pdf'):
        category = input('Enter Category: ')
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
            resume_data.append({'text': text, 'category': category,'candidate_resume_name': os.path.basename(file_path)})
            
    else:
        for root, dirs, files in os.walk(file_path):
            for file in files:
                if file.endswith('.pdf'):
                    with open(os.path.join(root, file), 'rb') as f:
                        category = os.path.basename(root)
                        text = ''
                        pdf_reader = PyPDF2.PdfReader(f)
                        for page_num in range(len(pdf_reader.pages)):
                            page = pdf_reader.pages[page_num]
                            text += page.extract_text()
                        data = pd.DataFrame({"text": [text], "category": [category],'candidate_resume_name': file})
                        resume_data.append(data)
                        
    return pd.concat(resume_data, ignore_index=True)

# %%
# Fill the past and exract the data
file_path = r"C:\Users\pcc\Desktop\data"
resume_data = extract_resume_data(file_path)

# %%
resume_data.head()
# Out:
#                                                 text    category  \
# 0  ACCOUNTANT\nSummary\nFinancial Accountant spec...  ACCOUNTANT
# 1  STAFF ACCOUNTANT\nSummary\nHighly analytical a...  ACCOUNTANT
# 2  ACCOUNTANT\nProfessional Summary\nTo obtain a ...  ACCOUNTANT
# 3  SENIOR ACCOUNTANT\nExperience\nCompany Name\n ...  ACCOUNTANT
# 4  SENIOR ACCOUNTANT\nProfessional Summary\nSenio...  ACCOUNTANT
#
#   candidate_resume_name
# 0          10554236.pdf
# 1          10674770.pdf
# 2          11163645.pdf
# 3          11759079.pdf
# 4          12065211.pdf

# %%
# Clean the text
def clean_resume_text(text):
    text=text.str.lower().str.strip()
    text=text.str.replace(r'[^a-zA-Z0-9\s\n]',"",regex=True)
    text=text.str.replace(r'\s+',' ',regex=True)
    return text

resume_data["cleaned_text"]=clean_resume_text(resume_data["text"])

# %%
# Extract the Sections
keywords=['summary','education','executive profile',
          'professional profile','accomplishments',
          'personal profile','work background',
          'academic profiles', 'qualifications',
          'other activities', 'experience','interests',
          'skills','achievements','publications','publication',
          'certifications','workshops','internships','trainings',
          'overview','objective','hobbies','jobs','position of responsibility'
]

resume_list=[]

def extract_content(text,keywords):
    content={}
    indices=[]
    keys=[]
    
    for key in keywords:
        key_start=text.find(key)
        if key_start != -1:
            next_key_index=text.find(key,key_start+1)
            if next_key_index !=-1:
                content[key]=text[key_start+len(key):next_key_index].strip()
            else:
                content[key]=text[key_start+len(key):].strip()
    return content     

for i in resume_data["cleaned_text"]:
    text=i
    parse_section_content=extract_content(text,keywords)
    resume_list.append(parse_section_content)
    
section_df=pd.DataFrame(resume_list)
section_df
# Out:
#                                                 summary  \
# 0     financial accountant specializing in financial...
# 1     highly analytical and detailoriented professio...
# 2     to obtain a position in a fastpaced business o...
# 3                                                   NaN
# 4     senior accountant who completes accounting act...
# ...                                                 ...
# 2479  i am a highly motivated educator and selfstart...
# 2480  to be employed as an administrative assistant ...
# 2481  highly ethical dependable and diligent expert ...
# 2482  talented early education professional with div...
# 2483  compassionate teaching professional delivering...
#
#                                               education  \
# 0     northern maine community college 1994 associat...
# 1     bachelor of science accounting may 2010 univer...
# 2     computer applications specialist certificate p...
# 3     emory university goizueta business school 5 20...
# 4     bachelor of business administration accounting...
# ...                                                 ...
# 2479  university of south florida 2002 bachelor of s...
# 2480  al software and the internet supervised an ave...
# 2481          university of phoenix 2007 master of arts
# 2482  professional with diverse experience in planni...
# 2483  and training mba marketing iglobal university ...
#
#                                         accomplishments  \
# 0     served on a tiger team which identified and re...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     found material misstatement in prepaid propert...
# ...                                                 ...
# 2479  student development education strategies goal ...
# 2480  administrative assistantsales representative m...
# 2481  designed effective lesson plans focused on age...
# 2482                                                NaN
# 2483                                                NaN
#
#                                              experience  \
# 0     company name july 2011 to november 2012 accoun...
# 1     staff accountant january 2014 to october 2014 ...
# 2     accountant january 2011 to november 2015 compa...
# 3     company name june 2011 to current senior accou...
# 4     in full life cycle of general ledger accountin...
# ...                                                 ...
# 2479  tenured hillsborough alliance for black school...
# 2480  creating excel databases and powerpoint presen...
# 2481  company name june 2012 to current teacher desi...
# 2482  in planning and implementing various activitie...
# 2483  in office administration and public speaking a...
#
#                                               interests  \
# 0     american society of military comptrollers addi...
# 1     alpha sigma phi officer and chair positions ja...
# 2                                                   NaN
# 3     fulton county casa board of directors member t...
# 4     world travelphotographygolfsoccermoviefashion ...
# ...                                                 ...
# 2479                                                NaN
# 2480  met regularly with parents and guardians to di...
# 2481                                                NaN
# 2482                                                NaN
# 2483                                                NaN
#
#                                                  skills  \
# 0     accounting general accounting accounts payable...
# 1     highlights dba quick books mas sage software m...
# 2     and attributes attributes selfmotivated and ho...
# 3     by drafting over forty memorandums that summar...
# 4     aderantcms excel quickbooks pro sql access pea...
# ...                                                 ...
# 2479  that have helped a plethora of teachers and st...
# 2480  will benefit the company technicallyadept job ...
# 2481  conflict resolution course development critica...
# 2482  cpr creative thinking delivery first aid polic...
# 2483  experience in office administration and public...
#
#                                          certifications  \
# 0     certified defense financial manager cdfm may 2...
# 1                                                   NaN
# 2                                                   NaN
# 3     and awards fulton county casa board of directo...
# 4     certified public accountant new york state dat...
# ...                                                 ...
# 2479                                                NaN
# 2480  skills accounting administrative basic billing...
# 2481                                                NaN
# 2482                                                NaN
# 2483                                                NaN
#
#                                               workshops  \
# 0     to participate and contribute to accounting po...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2479  centered on learning goals classroom managemen...
# 2480  fostered team collaboration between students t...
# 2481                                                NaN
# 2482                                                NaN
# 2483                                                NaN
#
#                                          qualifications  \
# 0                                                   NaN
# 1                                                   NaN
# 2     intermediate word advanced excel powerpoint in...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2479                                                NaN
# 2480                                                NaN
# 2481                                                NaN
# 2482                                                NaN
# 2483                                                NaN
#
#                                            achievements  ...  \
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3     by the highest performing junior year accounti...  ...
# 4                                                   NaN  ...
# ...                                                 ...  ...
# 2479                                                NaN  ...
# 2480                                                NaN  ...
# 2481                                                NaN  ...
# 2482                                                NaN  ...
# 2483                                                NaN  ...
#
#                                               objective professional profile  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 2479  s for all lessonsprojects and communicated wit...                  NaN
# 2480  s for all lessons units and projects to studen...                  NaN
# 2481  s by facilitating courses using my curriculum ...                  NaN
# 2482                                                NaN                  NaN
# 2483                                                NaN                  NaN
#
#      hobbies                                       publications  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4        NaN                                                NaN
# ...      ...                                                ...
# 2479     NaN                                                NaN
# 2480     NaN                                                NaN
# 2481     NaN                                                NaN
# 2482     NaN                                                NaN
# 2483     NaN  education and training mba marketing iglobal u...
#
#                                             publication personal profile  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 2479                                                NaN              NaN
# 2480                                                NaN              NaN
# 2481                                                NaN              NaN
# 2482                                                NaN              NaN
# 2483  and approved final versionsedited rewrote and ...              NaN
#
#      executive profile other activities  \
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
# ...                ...              ...
# 2479               NaN              NaN
# 2480               NaN              NaN
# 2481               NaN              NaN
# 2482               NaN              NaN
# 2483               NaN              NaN
#
#                                               trainings internships
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2479  company name august 2006 to june 2009 girls jv...         NaN
# 2480                                                NaN         NaN
# 2481                                                NaN         NaN
# 2482                                                NaN         NaN
# 2483                                                NaN         NaN
#
# [2484 rows x 22 columns]

# %%
# Drop unnessesary features
resume_data[["education","skills"]]=section_df[["education","skills"]]
resume_data=resume_data.drop(columns=["text","cleaned_text"],axis=1)
resume_data.head()
# Out:
#      category candidate_resume_name  \
# 0  ACCOUNTANT          10554236.pdf
# 1  ACCOUNTANT          10674770.pdf
# 2  ACCOUNTANT          11163645.pdf
# 3  ACCOUNTANT          11759079.pdf
# 4  ACCOUNTANT          12065211.pdf
#
#                                            education  \
# 0  northern maine community college 1994 associat...
# 1  bachelor of science accounting may 2010 univer...
# 2  computer applications specialist certificate p...
# 3  emory university goizueta business school 5 20...
# 4  bachelor of business administration accounting...
#
#                                               skills
# 0  accounting general accounting accounts payable...
# 1  highlights dba quick books mas sage software m...
# 2  and attributes attributes selfmotivated and ho...
# 3  by drafting over forty memorandums that summar...
# 4  aderantcms excel quickbooks pro sql access pea...

# %%
# create a csv of extracted data
resume_data.to_csv("C:/Users/pcc/Desktop/resume_data.csv")
